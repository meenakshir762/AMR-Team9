# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_json('Stock List.json')

# %%
df
# Out:
#         close      high      low    open symbol     volume                 id  \
# 0      129.41  133.6116  126.760  133.52   AAPL  143301887  HISTORICAL_PRICES
# 1      131.01  131.7400  128.430  128.89   AAPL   97664898  HISTORICAL_PRICES
# 2      126.60  131.0499  126.382  127.72   AAPL  155087970  HISTORICAL_PRICES
# 3      130.92  131.6300  127.860  128.36   AAPL  109578157  HISTORICAL_PRICES
# 4      132.05  132.6300  130.230  132.43   AAPL  105158245  HISTORICAL_PRICES
# ...       ...       ...      ...     ...    ...        ...                ...
# 16619   70.86   72.5450   70.400   70.50   SNAP    8874468  HISTORICAL_PRICES
# 16620   72.72   72.9699   70.800   71.20   SNAP    8615044  HISTORICAL_PRICES
# 16621   75.50   75.9300   73.670   74.01   SNAP   11055928  HISTORICAL_PRICES
# 16622   74.63   76.3700   73.720   75.82   SNAP    9663823  HISTORICAL_PRICES
# 16623   74.69   74.9760   73.490   74.31   SNAP    7901376  HISTORICAL_PRICES
#
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (15,8))
plt.xlabel('Date')
plt.ylabel('stock')
sns.lineplot(x = 'date', y = 'close',data = df)
sns.lineplot(x = 'date', y = 'open',data = df)
sns.lineplot(x = 'date', y = 'high',data = df)
sns.lineplot(x = 'date', y = 'low',data = df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='stock'>

# %%
x1= df['close']
x2 = df['open']
x3=df['high']
x4=df['low']
y=df['date']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
plt.xlabel('close')
plt.ylabel('high')
# Horizontal Bar Plot
plt.bar(x1[0:3], x3[0:3])
 
# Show Plot
plt.show()

# %%
df['date']
# Out:
# 0       2021-01-04
# 1       2021-01-05
# 2       2021-01-06
# 3       2021-01-07
# 4       2021-01-08
#            ...
# 16619   2021-08-19
# 16620   2021-08-20
# 16621   2021-08-23
# 16622   2021-08-24
# 16623   2021-08-25
# Name: date, Length: 16624, dtype: datetime64[ns]

# %%
df1=df[(df['date']=='2021-01-04')]
df1
# Out:
#          close       high       low     open symbol     volume  \
# 0       129.41   133.6116   126.760   133.52   AAPL  143301887
# 162     217.69   223.0000   214.810   222.53   MSFT   37130139
# 325    1728.24  1760.6500  1707.850  1757.54   GOOG    1901855
# 488    1726.13  1762.4899  1707.140  1760.00  GOOGL    1866195
# 651     296.84   307.8300   293.050   304.11   ADSK    1407015
# ...        ...        ...       ...      ...    ...        ...
# 15809   254.99   264.6500   253.510   261.05     EL    1909871
# 15972    86.87    89.3000    86.150    87.24   AMAT    8449949
# 16135    69.77    71.8300    69.390    71.78    BUD    1597562
# 16298    86.33    88.0600    85.160    87.56     JD    9204181
# 16461    49.59    50.7000    48.099    50.44   SNAP   18844890
#
#                       id    key subkey       date  ...      uLow    uVolume  \
# 0      HISTORICAL_PRICES   AAPL        2021-01-04  ...   126.760  143301887
# ...

# %%
df1['symbol'].unique()
# Out:
# array(['AAPL', 'MSFT', 'GOOG', 'GOOGL', 'ADSK', 'AMZN', 'FB', 'TSLA',
#        'TSM', 'NVDA', 'V', 'JPM', 'JNJ', 'BABA', 'WMT', 'UNH', 'BAC',
#        'MA', 'PG', 'HD', 'ASML', 'PYPL', 'DIS', 'ADBE', 'CMCSA', 'BBL',
#        'BHP', 'BMY', 'C', 'CHTR', 'CVX', 'HDB', 'HON', 'INTU', 'LIN',
#        'MCD', 'MDT', 'MRNA', 'MS', 'NEE', 'PM', 'QCOM', 'RY', 'SAP', 'SE',
#        'SHOP', 'TMUS', 'TXN', 'UPS', 'NKE', 'PFE', 'CRM', 'LLY', 'CSCO',
#        'ORCL', 'NFLX', 'TM', 'KO', 'NVO', 'XOM', 'DHR', 'VZ', 'ABT',
#        'INTC', 'TMO', 'PEP', 'ABBV', 'ACN', 'NVS', 'WFC', 'COST', 'AVGO',
#        'T', 'MRK', 'UL', 'UNP', 'LOW', 'BLK', 'SCHW', 'GS', 'SBUX', 'AXP',
#        'AMD', 'SONY', 'SNY', 'BA', 'RTX', 'AMT', 'AMGN', 'IBM', 'ISRG',
#        'TD', 'NOW', 'SQ', 'TGT', 'PDD', 'RIO', 'EL', 'AMAT', 'BUD', 'JD',
#        'SNAP'], dtype=object)

# %%
df1['symbol'].unique().shape
# Out:
# (102,)

# %%
df1.plot(x="date", y=["open","high","low","close"], kind="bar")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df2=df[(df['date']<='2021-01-06') & (df['date']>='2021-01-04') & (df['symbol']=='AAPL')]
df2
# Out:
#     close      high      low    open symbol     volume                 id  \
# 0  129.41  133.6116  126.760  133.52   AAPL  143301887  HISTORICAL_PRICES
# 1  131.01  131.7400  128.430  128.89   AAPL   97664898  HISTORICAL_PRICES
# 2  126.60  131.0499  126.382  127.72   AAPL  155087970  HISTORICAL_PRICES
#
#     key subkey       date  ...     uLow    uVolume     fOpen    fClose  \
# 0  AAPL        2021-01-04  ...  126.760  143301887  132.8956  128.8048
# 1  AAPL        2021-01-05  ...  128.430   97664898  128.2872  130.3973
# 2  AAPL        2021-01-06  ...  126.382  155087970  127.1227  126.0080
#
#       fHigh      fLow    fVolume      label  change  changePercent
# 0  132.9868  126.1672  143301887  Jan 4, 21    0.00         0.0000
# 1  131.1239  127.8294   97664898  Jan 5, 21    1.60         0.0124
# 2  130.4370  125.7910  155087970  Jan 6, 21   -4.41        -0.0337
#
# [3 rows x 26 columns]

# %%
df2.plot(x="date", y=["open","high","low","close"], kind="bar")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
plt.figure(figsize = (15,8))
plt.xlabel('Date')
plt.ylabel('stock')
sns.lineplot(x = 'date', y = 'close',data = df2)
sns.lineplot(x = 'date', y = 'open',data = df2)
sns.lineplot(x = 'date', y = 'high',data = df2)
sns.lineplot(x = 'date', y = 'low',data = df2)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='stock'>
